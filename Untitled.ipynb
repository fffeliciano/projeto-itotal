# %%
import csv
import numpy as np
import pandas as pd
import requests
import warnings
import openpyxl

# %%
# !pip install openpyxl
# Out:
# ...
#      ---------------------------------------- 242.1/242.1 kB 7.5 MB/s eta 0:00:00
# ...

# %%
with warnings.catch_warnings(record=True):
    warnings.simplefilter("always")
    df = pd.read_excel("./xml/Vendas_BR_20_de_janeiro_de_2023.xlsx", sheet_name="Vendas BR", skiprows=2, engine="openpyxl")  
    display(df)
# Out:
#          N.º de venda                    Data de venda  \
# 0    2000004970816330  20 de janeiro de 2023 23:20 hs.
# 1    2000004970494764  20 de janeiro de 2023 22:03 hs.
# 2    2000004970183174  20 de janeiro de 2023 20:56 hs.
# 3    2000004970010562  20 de janeiro de 2023 20:21 hs.
# 4    2000004969889174  20 de janeiro de 2023 19:58 hs.
# ..                ...                              ...
# 703  2000004850110896   1 de janeiro de 2023 11:33 hs.
# 704  2000004097591623   1 de janeiro de 2023 11:20 hs.
# 705  2000004849978576   1 de janeiro de 2023 10:11 hs.
# 706  2000004849934158   1 de janeiro de 2023 09:27 hs.
# 707  2000004849864210   1 de janeiro de 2023 07:15 hs.
#
#                                     Status  \
# 0    Processando no centro de distribuição
# 1    Processando no centro de distribuição
# 2    Processando no centro de distribuição
# 3    Processando no centro de distribuição
# 4    Processando no centro de distribuição
# ...

# %%
wb=openpyxl.load_workbook("./xml/Vendas_BR_20_de_janeiro_de_2023.xlsx")
for n in wb:
    print(n)
# Out:
# <Worksheet "Vendas BR">

# %%
wb.sheetnames
# Out:
# ['Vendas BR']

# %%
for d in wb['Vendas BR'].iter_rows(values_only=True):
    print(d)
# Out:
# ('Vendas  Status das suas vendas em 20 de janeiro de 2023, às 23:30 hs.', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)
# ('Vendas', None, None, None, None, None, None, None, None, None, None, None, 'Publicidade', 'Anúncios', None, None, None, None, None, None, 'Faturamento', None, None, None, None, 'Compradores', None, None, None, None, None, None, 'Envios', None, None, None, None, None, 'Devoluções', None, None, None, None, None, 'Reclamações', None, None)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 708 entries, 0 to 707
# Data columns (total 47 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   N.º de venda                              708 non-null    int64
#  1   Data de venda                             708 non-null    object
#  2   Status                                    708 non-null    object
#  3   Descrição do status                       708 non-null    object
#  4   Pacote de diversos produtos               708 non-null    object
#  5   Unidades                                  707 non-null    float64
#  6   Receita por produtos (BRL)                706 non-null    float64
#  7   Receita por envio (BRL)                   183 non-null    float64
#  8   Tarifa de venda e impostos                706 non-null    float64
#  9   Custo de envio                            530 non-null    float64
# ...

# %%
 tt = 21251

# %%
p = 575

# %%
var_tt = tt/100

# %%
var_p = p/100

# %%
var_tt
# Out:
# 212.51

# %%
import math

# %%
print(math.ceil(var_tt))
# Out:
# 213

# %%
res = math.ceil(var_tt)-math.ceil(var_p)

# %%
res
# Out:
# 207

# %%
res1 = math.fabs(var_p)

# %%
res1 = (int(res1))

# %%
res1
# Out:
# 5
